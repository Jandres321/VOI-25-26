# %% [markdown]
# # **Sesión 1:** Introducción a OpenCV y Espacios de color ⚙️🖼️

# %% [markdown]
# ## 0. Preparación

# %%
import cv2, numpy as np, matplotlib.pyplot as plt
import os
import cv2
import imageio
import numpy as np
from typing import List
from utils import get_hsv_color_ranges
import glob

# %% [markdown]
# ## **Apartado A: Uso basico de funciones de OpenCV**

# %% [markdown]
# El objetivo de este apartado es aprender a usar funcionalidades basica sobre el uso de OpenCV, para ello se hara uso de las imágenes en la carpeta ``data``.
#
# 1. **Tarea A.1**. Cargar una imagen ``cv2.imread()``.
# 2. **Tarea A.2.** Visualizar una imagen ``cv2.imshow()``.
# 3. **Tarea A.3.** Conversion de imagen de color a escala de grises ``cv2.cvtColor()``.
# 4. **Tarea A.4.** Cambia el tamaño de una imagen ``cv2.resize()`` a 200x200 píxeles.
# 5. **Tarea A.5.** Recorta el centro de la imagen a un tamaño 120x160.
# 6. **Tarea A.6.** Rota la imagen ``cv2.getRotationMatrix2D`` ``cv2.wrapAffine()``.
# 7. **Tarea A.7.** Guarda la imagen ``cv2.imwrite()``.

# %% [markdown]
# ### **Tarea A.1:** Cargar una imagen con ``cv2.imread()``

# %%
# Load an image from disk using cv2.imread('path/to/image.jpg').
img = cv2.imread('../data/004.jpg')

# %% [markdown]
# ### **Tarea A.2:** Visualizar la imagen con ``cv2.imshow()``

# %%
# Display the image using cv2.imshow().
cv2.imshow('Image', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ### **Tarea A.3:** Conversion de imagen de color a escala de grises ``cv2.cvtColor()``.

# %%
# Convert the image from color to grayscale using cv2.cvtColor().
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Check image shape → grayscale: (height, width), color: (height, width, channels).
print("Color shape:", img.shape)
print("Gray shape:", gray.shape)
# Display the image using cv2.imshow().
cv2.imshow('Gray Image', gray)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# Color shape: (683, 1024, 3)
# Gray shape: (683, 1024)

# %% [markdown]
# ### **Tarea A.4:** Cambia el tamaño de una imagen ``cv2.resize()`` a 200x200 píxeles.

# %%
# Resize the image to 200×200 pixels using cv2.resize().
resized = cv2.resize(img, (200, 200))
# Check the image shape
print("Resized shape:", resized.shape)
# Display the image using cv2.imshow().
cv2.imshow('Resized Image', resized)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# Resized shape: (200, 200, 3)

# %% [markdown]
# ### **Tarea A.5:** Recorta el centro de la imagen a un tamaño 120x160.

# %%
# Crop the center of the image 'img' with an approximate size of 120x160 pixels.
h, w = img.shape[:2]
cy, cx = h // 2, w // 2
roi = img[cy-60:cy+60, cx-80:cx+80]
# Check the image shape
print("ROI shape:", roi.shape)
# Display the image using cv2.imshow().
cv2.imshow('Cropped Image', roi)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ROI shape: (120, 160, 3)

# %% [markdown]
# ### **Tarea A.6:** Rota la imagen usando ``cv2.getRotationMatrix2D`` y ``cv2.wrapAffine()``.

# %%
# TODO: Rotate around the center using cv2.getRotationMatrix2D and cv2.warpAffine.
M = cv2.getRotationMatrix2D((cx, cy), 90, 2.0)
rotated = cv2.warpAffine(img, M, (w, h))
# TODO: Display the image using cv2.imshow().
cv2.imshow('Rotated Image', rotated)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ### **Tarea A.7:** Guarda la imagen con ``cv2.imwrite()``

# %%
# Save the image to disk as 'salida_opcionA_1.png' using cv2.imwrite().
cv2.imwrite('../data/salida_opcionA_1.png', rotated)
# Out:
# True

# %% [markdown]
# ## **Apartado B: Segmentación por color**

# %% [markdown]
# El objetivo de este apartado es segmentar los colores naranja y blanco de las imágenes en la carpeta ``data``.
#
# 1. **Tarea B.1**. Defina y ejecute el método para cargar imágenes ``load_imgs()``.
# 2. **Tarea B.2.** Defina los métodos ``show_image()`` y ``write_image()`` para visualizar y guardar imágenes.
# 3. **Tarea B.3.** Cambia el espacio de color de las imágenes a uno donde la crominancia y la intensidad estén separados (HSV).
# 4. **Tarea B.4.** Segmenta los colores anaranjados.
# 5. **Tarea B.5.** Segmenta los colores blancos.
# 6. **Tarea B.6.** Junta las máscaras para cada imagen (naranja + blanco) y segmenta cada una de ellas.
# 7. **Tarea B.7.** Guarda las imágenes.

# %% [markdown]
# ### **Tarea B.1:** Defina y ejecute el método para cargar imágenes ``load_images()``

# %%
def load_images(filenames: List) -> List:
    return [cv2.imread(filename) for filename in filenames]

# %%
# Build a list containing the paths of all images in the data folder
imgs_path = glob.glob('../data/*.jpg')
# Load all images using the load_images function
imgs = load_images(imgs_path)

# %% [markdown]
# ### **Tarea B.2**. Defina los métodos ``show_image()`` y ``write_image()`` para visualizar y guardar imágenes

# %%
# Complete the method, use every argument
def show_image(img: np.array, img_name: str = "Image"):
    cv2.imshow(img_name, img)
    cv2.waitKey()
    cv2.destroyAllWindows()

# Complete the method, use every argument
def write_image(output_folder: str, img_name: str, img: np.array):
    img_path = os.path.join(output_folder, img_name)    
    cv2.imwrite(img_path, img)

# %% [markdown]
# ### **Tarea B.3:** Cambie el espacio de color de las imágenes a uno donde la crominancia y la intensidad estén separados (HSV)

# %%
# Get a list with imgs in HSV color space
hsv_imgs = [cv2.cvtColor(img, cv2.COLOR_BGR2HSV) for img in imgs]

# %% [markdown]
# ### **Tarea B.4:** Segmente los colores anaranjados

# %%
# Define orange color range
light_orange = (1, 190, 200)
dark_orange = (255, 255, 255)

# Compute a list that contains a mask (which should segment orange colors) for every image.
orange_masks = [cv2.inRange(hsv, light_orange, dark_orange) for hsv in hsv_imgs]

# Compute a list that contains the result of multiplying the original image with its orange colors mask.
orange_segmented = [cv2.bitwise_and(img, img, mask=mask) for img, mask in zip(imgs, orange_masks)]

# Show an original image
show_image(imgs[4], "HSV Image 4")

# Show a mask
show_image(orange_masks[4], "Orange Mask 4")

# Show a segmented image
show_image(orange_segmented[4], "Orange Segmented 4")

# %% [markdown]
# ### **Tarea B.5:** Segmente los colores blancos.

# %% [markdown]
# Para detectar el rango de blancos complete la siguiente celda y ejecutela para investigar el rango de valores necesarios.

# %%
# Discover white color ranges
get_hsv_color_ranges(imgs[0])

# Define white color range
light_white = (0, 0, 75)
dark_white = (255, 75, 255)

# Compute a list that contains a mask (which should segment white colors) for every image.
white_masks = [cv2.inRange(hsv, light_white, dark_white) for hsv in hsv_imgs]

# Compute a list that contains the result of multiplying the original image with its white colors mask.
white_segmented = [cv2.bitwise_and(img, img, mask=mask) for img, mask in zip(imgs, white_masks)]

# Show an original image
show_image(imgs[4], "Original Image 4")

# Show a mask
show_image(white_masks[4], "White Mask 4")

# Show a segmented image
show_image(white_segmented[4], "White Segmented 4")
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 46 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 59 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 67 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 76 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 82 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 71 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 59 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 53 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 46 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 36 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin = 31 , sMin = 0, vMin = 0), (hMax = 255 , sMax = 255, vMax = 255)
# (hMin =
vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 124), (hMax = 255 , sMax = 141, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 124), (hMax = 255 , sMax = 139, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 124), (hMax = 255 , sMax = 138, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 124), (hMax = 255 , sMax = 136, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 124), (hMax = 255 , sMax = 129, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 124), (hMax = 255 , sMax = 125, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 124), (hMax = 255 , sMax = 118, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 124), (hMax = 255 , sMax = 117, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 124), (hMax = 255 , sMax = 114, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 124), (hMax = 255 , sMax = 112, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 124), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 126), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 129), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 131), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 133), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 134), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 135), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 138), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 140), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 142), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 143), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 144), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 145), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 147), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 149), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 255 , sMax = 108, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 255 , sMax = 106, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 255 , sMax = 104, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 255 , sMax = 100, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 255 , sMax = 97, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 255 , sMax = 95, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 255 , sMax = 94, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 255 , sMax = 93, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 152), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 153), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 154), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 155), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 156), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 158), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 160), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 161), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 163), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 165), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 167), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 170), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 171), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 173), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 174), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 175), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 176), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 178), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 182), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 187), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 190), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 193), (hMax = 255 , sMax = 92, vMax = 255)
# ...
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 1, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 7, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 10, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 12, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 13, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 14, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 16, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 19, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 20, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 16, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 10, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 7, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 4, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 3, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 1, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 2 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 7 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 9 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 11 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 13 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 16 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 19 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 21 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 7 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 254)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 251)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 248)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 246)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 245)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 242)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 239)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 237)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 248)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 254 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 252 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 246 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 242 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 239 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 237 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 234 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 227 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 224 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 221 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 215 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 206 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 201 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 197 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 196 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 195 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 193 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 190 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 185 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 172 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 155 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 139 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 128 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 121 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 116 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 109 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 98 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 85 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 74 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 62 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 51 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 45 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 42 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 41 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 36 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 31 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 19 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 25 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 56 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 123 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 187 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 225 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 88, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 85, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 83, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 81, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 80, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 78, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 77, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 76, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 72, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 71, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 70, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 69, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 67, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 65, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 63, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 61, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 60, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 58, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 62, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 65, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 68, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 71, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 72, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 76, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 77, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 78, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 79, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 81, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 85, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 92, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 94, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 90, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 85, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 81, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 80, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 78, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 77, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 126), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 132), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 135), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 136), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 140), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 141), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 142), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 143), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 145), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 149), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 152), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 154), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 155), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 158), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 161), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 162), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 164), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 165), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 167), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 169), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 171), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 172), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 173), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 174), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 175), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 178), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 181), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 184), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 187), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 189), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 191), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 192), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 196), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 198), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 201), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 203), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 204), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 205), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 207), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 209), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 210), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 209), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 207), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 201), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 194), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 189), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 181), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 174), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 167), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 162), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 154), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 144), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 135), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 122), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 116), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 105), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 100), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 91), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 88), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 87), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 86), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 87), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 88), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 91), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 94), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 98), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 104), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 106), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 107), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 106), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 105), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 104), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 103), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 100), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 98), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 95), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 93), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 91), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 89), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 87), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 83), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 80), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 78), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 77), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 76), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 75), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 74), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 75), (hMax = 255 , sMax = 74, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 76), (hMax = 255 , sMax = 74, vMax = 255)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[24], line 9
#       6 dark_white = (255, 255, 255)
#       8 # TODO Compute a list that contains a mask (which should segment white colors) for every image.
# ----> 9 white_masks = cv2.inRange()
#      11 # TODO Compute a list that contains the result of multiplying the original image with its white colors mask.
#      12 white_segmented = cv2.bitwise_and()
#
# error: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'inRange'
# > Overload resolution failed:
# >  - inRange() missing required argument 'src' (pos 1)
# >  - inRange() missing required argument 'src' (pos 1)

# %% [markdown]
# ### **Tarea B.6:** Junte las máscaras para cada imagen (naranja + blanco) y segmente cada una de ellas.

# %%
# TODO Join orange_masks and white_masks
fish_masks = None
    
# TODO Compute a list that contains the result of multiplying the original image with its complete mask.
fish = cv2.bitwise_and()

# TODO Show an original image
show_image()

# TODO Show a mask
show_image()

# TODO Show a segmented image
show_image()

# %% [markdown]
# ### **Tarea B.7:** Guarde las imágenes

# %%
# TODO Define your output folder and save every fish image
output_folder = None
write_image(output_folder=None, img_name=None, img=None)

# %% [markdown]
# ### **Pregunta B.1:** Segmente por color el logotipo de su marca favorita: descompóngalo en al menos 3 colores.

# %%
# TODO Homework

# %% [markdown]
# ### **Pregunta B.2:** ¿Qué ocurre si carga las imágenes con la función ``imageio.read()`` y luego la muestra con el método ``show_image()``? ¿A qué se debe este comportamiento?

# %%
def load_images(filenames: List) -> List:
    return [imageio.imread(filename) for filename in filenames]

# TODO Homework: Load images
question_imgs = load_images(None)


# TODO Homework: Show it
show_image(None)
